# %%
select count(*)
from dimdate;
# Out:
# (1 row affected)
#
# (No column name)
# ----------------
# 3652
# (1 row)
#
# Total execution time: 00:00:00.148

# %%
SELECT count(*)
from DimAccount;
# Out:
# (1 row affected)
#
# (No column name)
# ----------------
# 99
# (1 row)
#
# Total execution time: 00:00:00.146
